# %%
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from zipfile import ZipFile

# %%
with ZipFile('RIASEC_data12Dec2018.zip', 'r') as zip:
  zip.printdir()
# Out:
# File Name                                             Modified             Size
# RIASEC_data12Dec2018/                          2018-12-12 15:59:58            0
# RIASEC_data12Dec2018/.~lock.data.csv#          2018-12-12 15:50:54           71
# RIASEC_data12Dec2018/codebook.txt              2018-12-12 15:59:58         6088
# RIASEC_data12Dec2018/data.csv                  2018-12-12 15:18:46     29324901

# %%
with ZipFile('RIASEC_data12Dec2018.zip', 'r') as zip:
  #zip.extract('RIASEC_data12Dec2018/data.csv')
  zip.extractall()

# %%
data = pd.read_csv("RIASEC_data12Dec2018/data.csv", sep = "\t")
df = pd.DataFrame(data)
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    R1  R2  R3  R4  R5  R6  R7  R8  I1  I2  ...  orientation  race  voted  \
# 0   3   4   3   1   1   4   1   3   5   5  ...            1     1      2
# 1   1   1   2   4   1   2   2   1   5   5  ...            3     4      1
# 2   2   1   1   1   1   1   1   1   4   1  ...            1     4      2
# 3   3   1   1   2   2   2   2   2   4   1  ...            1     1      2
# 4   4   1   1   2   1   1   1   2   5   5  ...            3     1      2
#
#    married  familysize  uniqueNetworkLocation  country  source      major  \
# 0        1           1                      1       US       2        NaN
# 1        2           3                      1       US       1    Nursing
# 2        1           1                      1       US       1        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145828 entries, 0 to 145827
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   R1                     145828 non-null  int64
#  1   R2                     145828 non-null  int64
#  2   R3                     145828 non-null  int64
#  3   R4                     145828 non-null  int64
#  4   R5                     145828 non-null  int64
#  5   R6                     145828 non-null  int64
#  6   R7                     145828 non-null  int64
#  7   R8                     145828 non-null  int64
#  8   I1                     145828 non-null  int64
#  9   I2                     145828 non-null  int64
#  10  I3                     145828 non-null  int64
#  11  I4                     145828 non-null  int64
#  12  I5                     145828 non-null  int64
#  13  I6                     145828 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   R1             R2             R3             R4  \
# count  145828.000000  145828.000000  145828.000000  145828.000000
# mean        2.572846       2.106859       1.748738       2.293640
# std         1.318347       1.235213       1.120873       1.339156
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       1.000000       1.000000       1.000000
# 50%         3.000000       2.000000       1.000000       2.000000
# 75%         3.000000       3.000000       2.000000       3.000000
# max         5.000000       5.000000       5.000000       5.000000
#
#                   R5             R6             R7             R8  \
# count  145828.000000  145828.000000  145828.000000  145828.000000
# mean        1.749945       2.197815       2.017020       1.967215
# std         1.072175       1.273549       1.182839       1.184509
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
pd.set_option("display.max_rows", 100)
df.isna().sum()
# Out:
# R1                            0
# R2                            0
# R3                            0
# R4                            0
# R5                            0
# R6                            0
# R7                            0
# R8                            0
# I1                            0
# I2                            0
# I3                            0
# I4                            0
# I5                            0
# I6                            0
# I7                            0
# I8                            0
# A1                            0
# A2                            0
# A3                            0
# A4                            0
# A5                            0
# A6                            0
# A7                            0
# A8                            0
# S1                            0
# S2                            0
# S3                            0
# S4                            0
# S5                            0
# ...

# %%
df.drop(["Unnamed: 93"], axis = 1, inplace = True)

# %%
df["major"].nunique()
# Out:
# 15955

# %%
#pd.set_option("display.max_colwidth", 100)
np.set_printoptions(threshold= 16000)
arr = df["major"].unique()
np.array(arr)
# Out:
# array([nan, 'Nursing', 'education', 'Literature', 'Math',
#        'mathematics and science', 'family resource management',
#        'Counselling', 'business', 'Communication',
#        'Information Technology', 'languages', 'accounting', 'psychology',
#        'music', 'Pre-Nursing', 'literature', 'Public Health',
#        'civil engineering', 'Graphic Design', 'Social Work', 'art',
#        'geography/GIS', 'Sociology', 'institute kitchen services',
#        'Culinary', 'Business', 'logistics or economics', 'anthropology',
#        'Electronique', 'Social Work, Counseling', 'Psychology', 'IT',
#        'nursing; health physics; graphics', '-', 'Business admin',
#        'Management', 'English', 'pschology', 'Plant Science, Genetics',
#        'clinical psychology ', 'ge', 'foreign language',
#        'bachelor in math and science elementary educa',
#        'Science Forensic', 'diploma in science', 'engineering', 'law',
# ...

# %%
# NaN values in Major might represent an uneducated group
