# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt

# %%
with zipfile.ZipFile("/content/archive (4).zip","r") as zip2:
    data2 = zip2.extractall(path="/content")

# %%
csv2 = pd.read_csv("/content/IPIP-FFM-data-8Nov2018/data-final.csv",sep='\t')

# %%
csv2
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  EST1  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0   1.0
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0   2.0
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0   4.0
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0   3.0
# 4        3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0   1.0
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 759673   1.0   5.0   1.0   5.0   1.0   4.0   1.0   5.0   1.0    5.0   2.0
# 759674   3.0   1.0   5.0   1.0   5.0   1.0   4.0   2.0   5.0    2.0   2.0
# 759675   2.0   3.0   4.0   4.0   2.0   3.0   1.0   5.0   1.0    5.0   5.0
# 759676   3.0   2.0   4.0   3.0   5.0   1.0   2.0   3.0   4.0    2.0   2.0
# 759677   3.0   3.0   3.0   3.0   3.0   2.0   NaN   NaN   NaN    NaN   NaN
#
#         EST2  EST3  EST4  EST5  EST6  EST7  EST8  EST9  EST10  AGR1  AGR2  \
# ...

# %%
pd.set_option("display.max_rows",500)
csv2.isna().sum()
# Out:
# EXT1                     1783
# EXT2                     1783
# EXT3                     1783
# EXT4                     1783
# EXT5                     1783
# EXT6                     1783
# EXT7                     1784
# EXT8                     1784
# EXT9                     1784
# EXT10                    1784
# EST1                     1784
# EST2                     1784
# EST3                     1784
# EST4                     1784
# EST5                     1784
# EST6                     1784
# EST7                     1784
# EST8                     1784
# EST9                     1784
# EST10                    1784
# AGR1                     1784
# AGR2                     1784
# AGR3                     1784
# AGR4                     1784
# AGR5                     1784
# AGR6                     1784
# AGR7                     1784
# AGR8                     1784
# AGR9                     1784
# AGR10                    1784
# CSN1                     1784
# ...

# %%
csv2.dropna(inplace=True)

# %%
csv2.isna().sum()
# Out:
# EXT1                     0
# EXT2                     0
# EXT3                     0
# EXT4                     0
# EXT5                     0
# EXT6                     0
# EXT7                     0
# EXT8                     0
# EXT9                     0
# EXT10                    0
# EST1                     0
# EST2                     0
# EST3                     0
# EST4                     0
# EST5                     0
# EST6                     0
# EST7                     0
# EST8                     0
# EST9                     0
# EST10                    0
# AGR1                     0
# AGR2                     0
# AGR3                     0
# AGR4                     0
# AGR5                     0
# AGR6                     0
# AGR7                     0
# AGR8                     0
# AGR9                     0
# AGR10                    0
# CSN1                     0
# CSN2                     0
# CSN3                     0
# CSN4                     0
# ...

# %%
csv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756405 entries, 0 to 759676
# Columns: 110 entries, EXT1 to long_appx_lots_of_err
# dtypes: float64(106), object(4)
# memory usage: 640.6+ MB

# %%
csv2.drop(csv2.loc[:,'EXT1_E':'screenh'],axis=1,inplace=True)

# %%
csv2.drop(csv2.loc[:,'introelapse':'endelapse'],axis=1,inplace=True)

# %%
csv2.drop(csv2.loc[:,'lat_appx_lots_of_err':'long_appx_lots_of_err'],axis=1,inplace=True)

# %%
csv2 = csv2[csv2['IPC']==1]
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 5         False
#           ...
# 759667    False
# 759668    False
# 759671    False
# 759672    False
# 759673    False
# Name: IPC, Length: 516744, dtype: bool

# %%
csv2
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  EST1  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0   1.0
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0   2.0
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0   4.0
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0   3.0
# 5        3.0   3.0   4.0   2.0   4.0   2.0   2.0   3.0   3.0    4.0   3.0
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 759667   2.0   2.0   2.0   4.0   4.0   1.0   4.0   4.0   4.0    4.0   2.0
# 759668   1.0   5.0   3.0   5.0   4.0   4.0   1.0   5.0   1.0    5.0   5.0
# 759671   1.0   4.0   3.0   4.0   2.0   1.0   2.0   4.0   1.0    4.0   4.0
# 759672   3.0   2.0   3.0   3.0   3.0   3.0   4.0   4.0   1.0    4.0   3.0
# 759673   1.0   5.0   1.0   5.0   1.0   4.0   1.0   5.0   1.0    5.0   2.0
#
#         EST2  EST3  EST4  EST5  EST6  EST7  EST8  EST9  EST10  AGR1  AGR2  \
# ...

# %%
csv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759678 entries, 0 to 759677
# Empty DataFrame

# %%
import seaborn as sns

# %%
fig,ax = plt.subplots(figsize=(20,20))
sns.heatmap(csv2.corr(),square=True,cmap='viridis',ax=ax)

# %%
pd.set_option("display.max_columns",100)
csv2.corr()
# Out:
#                  EXT1      EXT2      EXT3      EXT4      EXT5      EXT6  \
# EXT1         1.000000 -0.439176  0.464833 -0.486689  0.478206 -0.323423
# EXT2        -0.439176  1.000000 -0.412273  0.552552 -0.500538  0.541775
# EXT3         0.464833 -0.412273  1.000000 -0.433449  0.554566 -0.321947
# EXT4        -0.486689  0.552552 -0.433449  1.000000 -0.459715  0.457623
# EXT5         0.478206 -0.500538  0.554566 -0.459715  1.000000 -0.409655
# EXT6        -0.323423  0.541775 -0.321947  0.457623 -0.409655  1.000000
# EXT7         0.581693 -0.444535  0.540954 -0.465724  0.588810 -0.337834
# EXT8        -0.368139  0.397786 -0.291678  0.488740 -0.312272  0.334500
# EXT9         0.470624 -0.364068  0.422393 -0.434490  0.421797 -0.304949
# EXT10       -0.410394  0.490812 -0.433824  0.538443 -0.486922  0.403870
# EST1        -0.084919  0.063247 -0.199060  0.155095 -0.095857  0.100378
# EST2         0.138874  0.000731  0.281648 -0.046373  0.134085 -0.002717
# ...

# %%
# Extraverted, Introverted, Agreeable, Disagreeable, Conscientious, Non-Conscientious, Emotionally Stable, Emotionally Unstable, Intellectual,
# Imaginative

# %%
#extraverted, agreeable, conscientious, emotionally unstable, imaginative
